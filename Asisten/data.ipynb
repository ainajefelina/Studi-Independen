# %%
import numpy as np
import pandas as pd
from io import StringIO

# %%
p4pka3 = pd.read_csv('P4-PKA3-PCX-Report.csv')

# %%
p4pka3.shape
# Out:
# (42, 43)

# %%
p4pka3.loc[0][1]
# Out:
# '99,69 %'

# %%
p4pka3.head()
# Out:
#                                                Files  \
# 0  Alifa Adawiya 195090207111012 Laporan P4 PKA3.pdf
# 1          Elok Milenia Shofa 195090207111052 P4.pdf
# 2   HANA ROFIDAH 195090201111044 TURBIDIMETRI(1).pdf
# 3      HANA ROFIDAH 195090201111044 TURBIDIMETRI.pdf
# 4  Laporan P4 Muhammad Adil Maulana 1950902001110...
#
#   Alifa Adawiya 195090207111012 Laporan P4 PKA3.pdf  \
# 0                                           99,69 %
# 1                                           27,82 %
# 2                                           13,96 %
# 3                                           13,78 %
# 4                                           13,14 %
#
#   Elok Milenia Shofa 195090207111052 P4.pdf  \
# 0                                   16,44 %
# 1                                   97,95 %
# 2                                   11,53 %
# 3                                   11,47 %
# 4                                   11,75 %
#
# ...

# %%
p4pka3[p4pka3.columns[1:]]=p4pka3[p4pka3.columns[1:]].replace(',','.',regex=True)

# %%
p4pka3[p4pka3.columns[1:]]=p4pka3[p4pka3.columns[1:]].replace('%','',regex=True)

# %%
p4pka3[p4pka3.columns[1:]]=p4pka3[p4pka3.columns[1:]].replace(' ','',regex=True)

# %%
p4pka3[p4pka3.columns[1:]]=p4pka3[p4pka3.columns[1:]].astype(float)

# %%
p4pka3.loc[0][1]
# Out:
# 99.69

# %%
p4pka3.head()
# Out:
#                                                Files  \
# 0  Alifa Adawiya 195090207111012 Laporan P4 PKA3.pdf
# 1          Elok Milenia Shofa 195090207111052 P4.pdf
# 2   HANA ROFIDAH 195090201111044 TURBIDIMETRI(1).pdf
# 3      HANA ROFIDAH 195090201111044 TURBIDIMETRI.pdf
# 4  Laporan P4 Muhammad Adil Maulana 1950902001110...
#
#    Alifa Adawiya 195090207111012 Laporan P4 PKA3.pdf  \
# 0                                              99.69
# 1                                              27.82
# 2                                              13.96
# 3                                              13.78
# 4                                              13.14
#
#    Elok Milenia Shofa 195090207111052 P4.pdf  \
# 0                                      16.44
# 1                                      97.95
# 2                                      11.53
# 3                                      11.47
# 4                                      11.75
#
# ...

# %%
p4pka3.shape
# Out:
# (42, 43)

# %%
p4pka3.reset_index(inplace=True)

# %%
p4pka3.
