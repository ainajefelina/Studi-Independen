# %% [markdown]
# # Plot Regresi
# - dengan library dari Seaborn yang ada di matplotlib, kita dapat membuat interface dengan level yang lebih tinggi untuk menggambar grafik statistika yang attraktif.
# - mginstal sea born dengan pip3 install seaborn
# - dan mengimportnya

# %%
import numpy as np
import pandas as pd
from PIL import Image
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

# %%
df_can= pd.read_excel('Canada.xlsx',
    sheet_name='Canada by Citizenship',
    skiprows = range(20),
    skipfooter=2)
df_can.drop(['AREA', 'REG', 'DEV', 'Type', 'Coverage'], axis = 1, inplace=True)
df_can.rename(columns={'OdName':'Country', 'AreaName':'Continrnt', 'RegName': 'Region'}, inplace=True)
df_can.columns=list(map(str, df_can.columns))
df_can.set_index('Country', inplace=True)
df_can['Total']=df_can.sum(axis=1)
years=list(map(str, range(1980,2014)))
# Out:
# /tmp/ipykernel_493/1919407535.py:9: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_can['Total']=df_can.sum(axis=1)

# %%
df_tot= pd.DataFrame(df_can[years].sum(axis=0))
df_tot.index=map(float, df_tot.index)
df_tot.reset_index(inplace=True)
df_tot.columns= ['year', 'total']
df_tot.head()
# Out:
#      year   total
# 0  1980.0   99137
# 1  1981.0  110563
# 2  1982.0  104271
# 3  1983.0   75550
# 4  1984.0   73417

# %%
ax = sns.regplot(x='year', y='total', data=df_tot)

# %%
ax = sns.regplot(x='year', y='total', data=df_tot, color='red')

# %%
ax = sns.regplot(x='year', y='total', data=df_tot, color='red', marker='+')

# %%
plt.figure(figsize=(15,10))
ax = sns.regplot(x='year', y='total', data=df_tot, color='red', marker='+')

# %%
plt.figure(figsize=(15, 10))
ax = sns.regplot(x='year', y='total', data=df_tot, color='green', marker='+', scatter_kws={'s': 200})

ax.set(xlabel='Year', ylabel='Total Immigration')
ax.set_title('Total Immigration to Canada from 1980 - 2013')
# Out:
# Text(0.5, 1.0, 'Total Immigration to Canada from 1980 - 2013')

# %%
plt.figure(figsize=(15, 10))

sns.set(font_scale=1.5)

ax = sns.regplot(x='year', y='total', data=df_tot, color='green', marker='+', scatter_kws={'s': 200})
ax.set(xlabel='Year', ylabel='Total Immigration')
ax.set_title('Total Immigration to Canada from 1980 - 2013')
# Out:
# Text(0.5, 1.0, 'Total Immigration to Canada from 1980 - 2013')

# %%
plt.figure(figsize=(15, 10))

sns.set(font_scale=1.5)
sns.set_style('ticks')

ax = sns.regplot(x='year', y='total', data=df_tot, color='green', marker='+', scatter_kws={'s': 200})
ax.set(xlabel='Year', ylabel='Total Immigration')
ax.set_title('Total Immigration to Canada from 1980 - 2013')
# Out:
# Text(0.5, 1.0, 'Total Immigration to Canada from 1980 - 2013')

# %%
plt.figure(figsize=(15, 10))

sns.set(font_scale=1.5)
sns.set_style('whitegrid')

ax = sns.regplot(x='year', y='total', data=df_tot, color='green', marker='+', scatter_kws={'s': 200})
ax.set(xlabel='Year', ylabel='Total Immigration')
ax.set_title('Total Immigration to Canada from 1980 - 2013')
# Out:
# Text(0.5, 1.0, 'Total Immigration to Canada from 1980 - 2013')

# %% [markdown]
# ## Total Immigrasi dari Denmark, Norway, dan Sweden

# %%
df_dns=df_can.loc[['Denmark', 'Norway', 'Sweden'], years].transpose()
df_dns_total = pd.DataFrame(df_dns.sum(axis=1))
df_dns_total.reset_index(inplace=True)
df_dns_total.columns=['years', 'total']
df_dns_total['years']=df_dns_total['years'].astype(int)

plt.figure(figsize=(15,10))
sns.set(font_scale=1.5)
sns.set_style('whitegrid')
ax= sns.regplot(x='years', y='total', data=df_dns_total, color='red', marker='+', scatter_kws={'s':200})
ax.set_title('Total Immigration from Denmark, Sweden, and Norway to Canada from 1980 - 2013')
ax.set(xlabel='Year', ylabel='Total Immigration')
# Out:
# [Text(0.5, 0, 'Year'), Text(0, 0.5, 'Total Immigration')]
